# %%
day_list = ['Sunday','Monday','Tuseday','Wensday','Thursday','Friday','Saterday']
upper_day_list = []
for day in day_list:
    upper_day_list.append(day[:3].upper())
print(upper_day_list)
# Out:
# ['SUN', 'MON', 'TUS', 'WEN', 'THU', 'FRI', 'SAT']
