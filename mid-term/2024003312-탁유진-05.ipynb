# %% [markdown]
# 모든 사람이 최소 1조각씩 먹을 수 있도록 주문해야 할 피자의 최소 개수를 계산하는 코드

# %%
n = int(input("파티에 참석한 사람 수를 입력해주세요(Anna 포함): "))
pizza = (n-1) // 8 + 1
print(f"피자는 최소 {pizza}개 필요합니다.")
# Out:
# 파티에 참석한 사람 수를 입력해주세요(Anna 포함):  17
# 피자는 최소 3개 필요합니다.
